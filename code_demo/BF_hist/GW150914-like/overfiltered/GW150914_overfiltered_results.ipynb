# %%
import numpy as np
import matplotlib.pyplot as pl

# %%
data = np.loadtxt("results/GW150914_221_overfiltered_ALL.dat")
[SNRtot_MF, SNRtot_opt, evidence220_221, evidence220, evidence221, nofilter] = data.T

# %%
pl.plot(SNRtot_MF, evidence220, 'o')
# pl.ylim(-100, 10)
